# %% [markdown]
# ### Python as the Zen of Data Science
# - - - - - - - - - - - - - - - - - - - - - - -
# **TRAVIS OLIPHANT , PETER WANG** *from Continuum Analytics*
#
# (*comes across as a bit... hrm.*)
#
# Theme: python is the 'right pratice, right attitude, right.. something' = Zen [of data science]
#
# ** *Let the data drive the analysis, not the technology stack* **
#
# ###### PyData Stack
# Few things I didn't know:
# - Numba ("high performance functions written directly in Python" -- JIT compiled to etc.)
# - Bokeh (visualizations)
# - Sympy (symbolic math)
# - Blaze (higher level spark interface)
# - dask
#
# **Anaconda**: *(it's not clear to me if anaconda is anything more than glorified pip + virtualenv wrappers. which isn't nothing, but, y'know.)*
# *(anaconda might be a good starting point for sara)*
# - claim is that it supports C/C+ environments effectively
#
# **acluster**: (Anaconda cluster) Support for building out spark clusters? Handy. Should certainly check this out.
#
# **Blaze**: "SQL for Python" -- not the most appealing description...
# Talking about glue code / glue languages a lot
# - interface to query data on different storage systems (csv, sql, mongodb, json, s3, spark, etc.)
# - datashape: extension to dtype *(what is dtype?)*
#
# **dask**: "out-of-core python"
# - parallel computing framework
# - dask arrays/dataframes
# - distributed scheduler
#
# worth checking out
#
# **distributed**: library for doing distributed etc.
#
# **numba**: JIT compiled stuff in python
# - also cuda-python is avaialable...

# %%
# recommended by Travis Oliphant 
import this

# %% [markdown]
# ### How Python Found Its Way Into Astronomy
# - - - - - - - - - - - - - - - - - - - - - - - - -
# **Perry Greenfield** *Space Telescope Science Institute*
#
# ###### Role of the software
# - Calibration
# - Combine / reduce data
# - Tools for analysis
# - Simulation
# - Planning for observations
#
# ###### History of software
# - IRAF: Custom language & scripting language compiled down to F66 / C
#     - Full framework, down to OS
#     - Effectively a snapshot of 1980 UNIX
#     - Fiefdom / politics
# - Attempts to resolve:
#     - Forking
#     - Rewriting
#     - Politics got in the way
# - PyRAF: 1998
#     - Expanded in 2000
#     - Started using Numeric, the numarray, then numpy
#     - PyFITS: support for standard astronomy data format
# - Uses
#     - astrodrizzle
#         - combine multiple exposures from different pointings
#         - and reject cosmic rays
#         - and deal with distortion
#         - and fractional pixel offset
#         - errors of .003 pixels are noticeable!
#     - james web space telescope
#         - to be launched 2018?
#         - much bigger!
#             - infrared telescope; mirrors must be kept cold
#             - launched to L2 point, not really serviceable
#             - mirrors need *nanometer* level stability
#         - Due to distance, not much data coming back
#             - but simulation in testing generates a ton
# - Most new applications are written in python now
# - Python is good
#     - Accessible!
#     - Interactive!
#     - Technical superiority? not sufficient.

# %% [markdown]
# ### Memex: Mining the Deep Web
# - - - - - - - - - - - - - - - - - -
# **Katrina Riehl** *Continuum Analytics*
#
# http://www.darpa.mil/program/memex
#
# - '85% of the web isn't visible'
# - indexing and searching things like
#     - material research documents (non-text searching/indexing)
#     - human trafficking
#     - child exploitation
#     - weapons sales
#     - financial fraud
#     - counterfeit electronics
# - memex team code is all open source
#     - http://opencatalog.darpa.mil/MEMEX.html
# - analytics pipeline
#     - pretty normal
#     - crawlers/scrapers -> extraction -> indexing -> visualization / searching
# - memex explorer
#     - build on django/elasticsearch
#     - using bokeh / kibana dashboards *(kibana?)*
#     - apache nutch / **apache tika** for crawling *(**tika** may be very useful for replacing keyview!)*
#     - *(whee, django)*
#     - NYU domain discovery tool sounds interesting
# - domain discovery
#     - termite plot in bokeh
#         - display terms that contribute to clusters
#     - LDAVis
#         - cluster comparison tool

# %% [markdown]
# ### The Future of Machine Learning Panel Discussion
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# **Stefan Karpinski, Andreas Mueller, Jared Lander, Julia Lintern** *Julia, socketlearn core, R & data scientist, Metis data science instructor*
#
# - Most over-hyped in ML?
#     - neural networks, obv
#         - everyone agrees, since there's such poor transparency
#     - spark
#         - doesn't seem that useful for ML, since ML data is typically small
#             - argues more for spark for preprocessing
#         - *(this is just like with hadoop, yeah?)*
#         - counter: break hadoop dependence
# - 'the point of the null' *(what the hell is this guy talking about?)*
#     - second guy: i think null hypothesis testing & statistical significance is stupid!
#
# Yikes. Tuned out.

# %% [markdown]
# ### The Pain of Discipline and the Power of Not Yet
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# **Cornelia Levy-Bencheton** *CLB Strategic Consulting (Author of _Women in Data_)*
#
# Retention of women in tech is especially poor: 6% of tech workers (57% of bachelors grads are women; 51% of phds even)
#
# *(phrases i don't like: "failure is amortized into experience")*

# %% [markdown]
# ### Julia for Data Analysis and Beyond
# (see the julia notebook!)

# %% [markdown]
# ### New Project Features- scikit-learn, pandas, matplotlib, & jupyter
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# **ANDREAS MUELLER, BRIAN GRANGER, JEFF REBACK, MICHAEL DROETTBOOM**
#
# ##### matplotlib
# - %matplotlib notebook *should* work
#     - working on python3 for this machine?
# - cycler uses different colormaps
# - lots of new colormaps added
#     - viridia will be new default in 2.0
# - labeled data support
#
# ##### pandas
# - 0.15
#     - timedelta indices
#     - datetimes w/timezones
# - 0.16.x
#     - chained calls
#     - pipes: send data to other libs i think
#     - sample (using this already)
#     - releases the gil
#     - .plot accessor
#         - .plot.line, for example
#     - .sort_values vs .sort_index
#     - df.style
#         - colorize dataframe output
#         - cylon style
#
# ##### scikit-learn 0.17
# - only 2D representations
# - faster logistic regression (LR-SAG)
# - improved cross-validation
#
# ##### jupyter
# - github notebook rendering
# - jupyter governance
# - multi-cell select
# - find & replace
# - command palette (command-shift-p)
# - coming in 5.0
#     - jupyter workbench providing components in one browser tab

# %%
# %matplotlib notebook
import pandas as pd

foo = pd.Series(range(500))
foo.plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Lightning Talks
# - - - - - - - - - -
#
# ###### bokeh
# bokeh does cool stuff
#
# ##### exploratory data analysis
# - this guy says never use k-means for clustering. fair enough.
#     - for all the reasons you'd expect
# - recommends:
#     - dbscan (sklearn)
#     - robust single linkage (coaxlab/debacl)
#     - hdbscan imcinnes/hdbscan
#
# ##### machine psychiatry by adam chekroud
#
# ##### rwatch
# - rwatch module sets read watches on code objects
#     - set a readwatch with an exception to sandbox...
#     - modify the value returned from the object
#     - you can do dirty things with defaultdict
#     - you can do dirty things to make pointers
#
# ##### abstract rendering by jim crist
# - inspired Cottam2014 IU paper (indiana)
# - printingcode color lecture at some unknown url
#
# ##### credit valuation adjustment with  numba & monte carlo by someone
